# %% [markdown]
# <a href="https://colab.research.google.com/github/fgsantosti/programacaodispositivosmoveis/blob/main/PDM_Atividade03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Desafio de Desenvolvimento de Aplicativo: Flag Game**
#
# #### **Descrição do Desafio**
# Os alunos deverão desenvolver um aplicativo chamado **Flag Game** utilizando o framework Flutter, com o objetivo de testar os conhecimentos dos jogadores sobre as bandeiras de países de todo o mundo. O aplicativo deverá ser interativo e oferecer diferentes modos de jogo, com configurações personalizáveis para o tempo de resposta. O projeto será avaliado com base na funcionalidade, design, organização do código, e criatividade na implementação.
#
# ---
#
# #### **Requisitos do Aplicativo**
#
# ##### **1. Tela Inicial (Menu Principal)**
# - Apresentar as seguintes opções:
#   - **Jogar por Continente:**
#     - O jogador escolhe um continente (África, América, Ásia, Europa, Oceania).
#     - O jogo seleciona aleatoriamente bandeiras apenas do continente escolhido.
#   - **Jogo Aleatório:**
#     - Bandeiras de todos os países do mundo são sorteadas de forma aleatória.
#   - **Configuração do Tempo:**
#     - O jogador escolhe o tempo total do jogo:
#       - 30 segundos, 60 segundos, 3 minutos ou 5 minutos.
#
# ---
#
# ##### **2. Tela de Jogo**
# - Cada pergunta deve conter:
#   - Uma bandeira exibida no topo da tela.
#   - Quatro opções de resposta (nome de países).
#   - Um temporizador indicando o tempo restante para responder.
# - Após selecionar uma resposta:
#   - Mostrar se o jogador acertou ou errou.
#   - Ir automaticamente para a próxima pergunta.
#
# ---
#
# ##### **3. Lógica do Jogo**
# - **Banco de Dados de Bandeiras:**
#   - Criar um arquivo ou usar um pacote que contenha as bandeiras e os nomes dos países associados.
#   - Os dados devem ser organizados por continentes para facilitar o modo "Jogar por Continente".
# - **Pontuação:**
#   - Incrementar a pontuação a cada resposta correta.
#   - Exibir a pontuação final ao término do jogo.
# - **Controle de Tempo:**
#   - Implementar o cronômetro conforme a configuração de tempo selecionada.
#   - Encerrar o jogo quando o tempo acabar.
#
# ---
#
# ##### **4. Tela de Resultados**
# - Exibir as informações ao final de cada partida:
#   - Total de perguntas respondidas.
#   - Total de acertos.
#   - Percentual de acertos (%).
# - Um botão para retornar ao menu principal.
#
# ---
#
# #### **Funcionalidades Extras (Opcional)**
# Os alunos podem incrementar o aplicativo com funcionalidades extras para ganhar mais pontos:
# 1. **Modo de Dificuldade:**
#    - Fácil: Exibir bandeiras apenas de países mais conhecidos.
#    - Difícil: Incluir bandeiras de países menos conhecidos.
# 2. **Leaderboard:**
#    - Salvar as pontuações mais altas localmente para exibir os melhores resultados dos jogadores.
# 3. **Idiomas:**
#    - Suporte a múltiplos idiomas (português, inglês, espanhol).
# 4. **Animações:**
#    - Animações ao acertar ou errar uma pergunta.
#
# ---
#
# #### **Requisitos Técnicos**
# 1. **Componentes Obrigatórios:**
#    - Uso de widgets básicos do Flutter: `Scaffold`, `Text`, `Buttons`, `Images`.
#    - Navegação entre telas usando o `Navigator`.
#    - Gerenciamento de estados usando `setState` ou soluções mais avançadas (opcional).
#
# 2. **Banco de Dados de Bandeiras:**
#    - Recomendado usar um arquivo JSON contendo os nomes dos países e links para as bandeiras.
#    - Sugestão de fonte: [Rest Countries API](https://restcountries.com/) ou arquivos locais.
#
# 3. **Armazenamento Local:**
#    - Utilize `shared_preferences` para salvar as pontuações mais altas.
#
# ---
#
# #### **Entrega e Avaliação**
# 1. **O que deve ser entregue:**
#    - Código-fonte completo do projeto no GitHub.
#    - Documentação no arquivo README.md, contendo:
#      - Descrição do aplicativo.
#      - Passos para rodar o projeto.
#      - Recursos utilizados.
#    - Um vídeo explicativo mostrando o funcionamento do aplicativo.
#
# 2. **Critérios de Avaliação:**
#    - **Funcionalidade (50%):** O aplicativo cumpre todos os requisitos?
#    - **Interface (20%):** O design é agradável e responsivo?
#    - **Organização do Código (15%):** Código bem estruturado e comentado.
#    - **Criatividade (15%):** Incrementos e diferenciais implementados.
#
# ---
#
# #### **Dicas para os Alunos**
# 1. Divida o trabalho em etapas:
#    - Comece pela lógica básica do jogo.
#    - Depois implemente as telas e a navegação.
#    - Por último, insira melhorias e funcionalidades extras.
# 2. Teste frequentemente para garantir que o aplicativo esteja funcionando corretamente.
# 3. Reutilize componentes para evitar redundâncias no código.
#
# Boa sorte! 🚀 Se precisar de ajuda ou tirar dúvidas, estarei por aqui para orientar!
